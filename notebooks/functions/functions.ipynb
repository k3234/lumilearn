# %% [markdown]
# # Functions
#
# 难度: 高一 | 学科: 数学 | 生成时间: 2026-05-30
#
# > 本笔记本由 LumiLearn notebook_generator 基于 learn-shit 教学风格生成

# %% [markdown]
# ## 环境设置
#
# 导入必要的库，配置 matplotlib 中文显示

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Markdown, Latex

plt.rcParams['font.sans-serif'] = ['SimHei', 'Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = False
print('环境就绪!')

# %% [markdown]
# ## 学习路线
#
# 1. 定义域
# 2. 值域
# 3. 单调性
# 4. 奇偶性
# 5. 反函数
#
# 共 5 个知识点

# %% [markdown]
# ## 概念 1: 定义域
#
# *数学 · 高一*
#
# 在下方代码中探索 定义域 的核心原理。修改参数观察变化。

# %%
# 定义域 - 交互式探索
print('当前知识点: 定义域')
print(f'主题: Functions')
print(f'难度: 高一')

# TODO: 在此编写探索代码
# 提示：使用 numpy 计算，matplotlib 可视化

# %% [markdown]
# ## 概念 2: 值域
#
# *数学 · 高一*
#
# 在下方代码中探索 值域 的核心原理。修改参数观察变化。

# %%
# 值域 - 交互式探索
print('当前知识点: 值域')
print(f'主题: Functions')
print(f'难度: 高一')

# TODO: 在此编写探索代码
# 提示：使用 numpy 计算，matplotlib 可视化

# %% [markdown]
# ## 概念 3: 单调性
#
# *数学 · 高一*
#
# 在下方代码中探索 单调性 的核心原理。修改参数观察变化。

# %%
# 单调性 - 交互式探索
print('当前知识点: 单调性')
print(f'主题: Functions')
print(f'难度: 高一')

# TODO: 在此编写探索代码
# 提示：使用 numpy 计算，matplotlib 可视化

# %% [markdown]
# ## 概念 4: 奇偶性
#
# *数学 · 高一*
#
# 在下方代码中探索 奇偶性 的核心原理。修改参数观察变化。

# %%
# 奇偶性 - 交互式探索
print('当前知识点: 奇偶性')
print(f'主题: Functions')
print(f'难度: 高一')

# TODO: 在此编写探索代码
# 提示：使用 numpy 计算，matplotlib 可视化

# %% [markdown]
# ## 概念 5: 反函数
#
# *数学 · 高一*
#
# 在下方代码中探索 反函数 的核心原理。修改参数观察变化。

# %%
# 反函数 - 交互式探索
print('当前知识点: 反函数')
print(f'主题: Functions')
print(f'难度: 高一')

# TODO: 在此编写探索代码
# 提示：使用 numpy 计算，matplotlib 可视化

# %% [markdown]
# ## 综合实践
#
# 将以上 5 个概念灵活运用，完成一个小型实践项目。

# %%
# 综合实践项目
# 题目：运用以上概念解决实际问题

# 1. 设定参数
# 2. 编写算法
# 3. 可视化结果
# 4. 验证正确性

print('综合实践完成!')

# %% [markdown]
# ## 课后练习
#
# 1. 修改参数观察输出变化
# 2. 尝试用不同方法复现同样效果
# 3. 思考本节知识在实际中的应用场景
# 4. 查阅延伸资料，深化理解
